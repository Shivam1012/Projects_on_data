# %%
import pandas as pd
import numpy as np

# %%
dropout= pd.read_csv("dropout_ratio_2012_2015.csv")

# %%
dropout.shape
# Out:
# (110, 14)

# %%
dropout.head()
# Out:
#          State_UT     year Primary_Boys Primary_Girls Primary_Total  \
# 0   A & N Islands  2012-13         0.83          0.51          0.68
# 1   A & N Islands  2013-14         1.35          1.06          1.21
# 2   A & N Islands  2014-15         0.47          0.55          0.51
# 3  Andhra Pradesh  2012-13          3.3          3.05          3.18
# 4  Andhra Pradesh  2013-14         4.31          4.39          4.35
#
#   Upper Primary_Boys Upper Primary_Girls Upper Primary_Total Secondary _Boys  \
# 0     Uppe_r_Primary                1.09                1.23            5.57
# 1                 NR                1.54                0.51            8.36
# 2               1.44                1.95                1.69           11.47
# 3               3.21                3.51                3.36           12.21
# 4               3.46                4.12                3.78           11.95
#
#   Secondary _Girls Secondary _Total HrSecondary_Boys HrSecondary_Girls  \
# 0             5.55             5.56            17.66             10.15
# 1             5.98              7.2            18.94              12.2
# 2             8.16             9.87            21.05             12.21
# 3            13.25            12.72             2.66                NR
# 4            13.37            12.65            12.65             10.85
#
#   HrSecondary_Total
# 0             14.14
# 1             15.87
# 2             16.93
# 3              0.35
# 4             11.79

# %%
dropout.tail()
# Out:
#         State_UT     year Primary_Boys Primary_Girls Primary_Total  \
# 105  West Bengal  2013-14         3.44          2.37          2.91
# 106  West Bengal  2014-15         2.13          0.79          1.47
# 107    All India  2012-13         4.68          4.66          4.67
# 108    All India  2013-14         4.53          4.14          4.34
# 109    All India  2014-15         4.36          3.88          4.13
#
#     Upper Primary_Boys Upper Primary_Girls Upper Primary_Total  \
# 105               5.63                 3.1                4.31
# 106               5.84                2.88                 4.3
# 107                2.3                4.01                3.13
# 108               3.09                4.49                3.77
# 109               3.49                 4.6                4.03
#
#     Secondary _Boys Secondary _Girls Secondary _Total HrSecondary_Boys  \
# 105           16.73            19.77            18.34             8.03
# 106           16.33            19.06             17.8             8.18
# 107           14.54            14.54            14.54               NR
# 108           17.93            17.79            17.86             1.48
# 109           17.21            16.88            17.06             0.25
#
#     HrSecondary_Girls HrSecondary_Total
# 105              7.76               7.9
# 106              8.04              8.11
# 107                NR                NR
# 108              1.61              1.54
# 109                NR                NR

# %%
dropout.columns
# Out:
# Index(['State_UT', 'year', 'Primary_Boys', 'Primary_Girls', 'Primary_Total',
#        'Upper Primary_Boys', 'Upper Primary_Girls', 'Upper Primary_Total',
#        'Secondary _Boys', 'Secondary _Girls', 'Secondary _Total',
#        'HrSecondary_Boys', 'HrSecondary_Girls', 'HrSecondary_Total'],
#       dtype='object')

# %%
dropout.isna()
# Out:
#      State_UT   year  Primary_Boys  Primary_Girls  Primary_Total  \
# 0       False  False         False          False          False
# 1       False  False         False          False          False
# 2       False  False         False          False          False
# 3       False  False         False          False          False
# 4       False  False         False          False          False
# ..        ...    ...           ...            ...            ...
# 105     False  False         False          False          False
# 106     False  False         False          False          False
# 107     False  False         False          False          False
# 108     False  False         False          False          False
# 109     False  False         False          False          False
#
#      Upper Primary_Boys  Upper Primary_Girls  Upper Primary_Total  \
# 0                 False                False                False
# 1                 False                False                False
# 2                 False                False                False
# 3                 False                False                False
# 4                 False                False                False
# ..                  ...                  ...                  ...
# 105               False                False                False
# 106               False                False                False
# 107               False                False                False
# 108               False                False                False
# 109               False                False                False
#
#      Secondary _Boys  Secondary _Girls  Secondary _Total  HrSecondary_Boys  \
# 0              False             False             False             False
# 1              False             False             False             False
# 2              False             False             False             False
# 3              False             False             False             False
# 4              False             False             False             False
# ..               ...               ...               ...               ...
# 105            False             False             False             False
# 106            False             False             False             False
# 107            False             False             False             False
# 108            False             False             False             False
# 109            False             False             False             False
#
#      HrSecondary_Girls  HrSecondary_Total
# 0                False              False
# 1                False              False
# 2                False              False
# 3                False              False
# 4                False              False
# ..                 ...                ...
# 105              False              False
# 106              False              False
# 107              False              False
# 108              False              False
# 109              False              False
#
# [110 rows x 14 columns]

# %%
dropout.isna().any()
# Out:
# State_UT               False
# year                   False
# Primary_Boys           False
# Primary_Girls          False
# Primary_Total          False
# Upper Primary_Boys     False
# Upper Primary_Girls    False
# Upper Primary_Total    False
# Secondary _Boys        False
# Secondary _Girls       False
# Secondary _Total       False
# HrSecondary_Boys       False
# HrSecondary_Girls      False
# HrSecondary_Total      False
# dtype: bool

# %%
data_wb=dropout[dropout['State_UT']=='West Bengal']
print(data_wb.head())
# Out:
#         State_UT     year Primary_Boys Primary_Girls Primary_Total  \
# 104  West Bengal  2012-13         6.88          5.71           6.3
# 105  West Bengal  2013-14         3.44          2.37          2.91
# 106  West Bengal  2014-15         2.13          0.79          1.47
#
#     Upper Primary_Boys Upper Primary_Girls Upper Primary_Total  \
# 104               6.29                4.16                5.18
# 105               5.63                 3.1                4.31
# 106               5.84                2.88                 4.3
#
#     Secondary _Boys Secondary _Girls Secondary _Total HrSecondary_Boys  \
# 104           14.95            19.41             17.3             7.81
# 105           16.73            19.77            18.34             8.03
# 106           16.33            19.06             17.8             8.18
#
#     HrSecondary_Girls HrSecondary_Total
# 104              8.49              8.13
# 105              7.76               7.9
# 106              8.04              8.11

# %%
dropout.groupby('State_UT').groups
# Out:
# {'A & N Islands': [0, 1, 2], 'All India': [107, 108, 109], 'Andhra Pradesh': [3, 4, 5], 'Arunachal  Pradesh': [6], 'Arunachal Pradesh': [7, 8], 'Assam': [9, 10, 11], 'Bihar': [12, 13, 14], 'Chandigarh': [15, 16, 17], 'Chhattisgarh': [18, 19, 20], 'Dadra & Nagar Haveli': [21, 22, 23], 'Daman & Diu': [24, 25, 26], 'Delhi': [27, 28, 29], 'Goa': [30, 31, 32], 'Gujarat': [33, 34, 35], 'Haryana': [36, 37, 38], 'Himachal Pradesh': [39, 40, 41], 'Jammu & Kashmir': [42, 43, 44], 'Jharkhand': [45, 46, 47], 'Karnataka': [48, 49, 50], 'Kerala': [51, 52, 53], 'Lakshadweep': [54, 55, 56], 'Madhya  Pradesh': [57], 'Madhya Pradesh': [58, 59], 'Maharashtra': [60, 61, 62], 'Manipur': [63, 64, 65], 'Meghalaya': [66, 67, 68], 'Mizoram': [69, 70, 71], 'Nagaland': [72, 73, 74], 'Odisha': [75, 76, 77], 'Puducherry': [78, 79, 80], 'Punjab': [81, 82, 83], 'Rajasthan': [84, 85, 86], 'Sikkim': [87, 88, 89], 'Tamil  Nadu': [90], 'Tamil Nadu': [91, 92], 'Telangana': [93, 94], 'Tripura': [95, 96, 97], 'Uttar Pradesh': [98, 99, 100], 'Uttarakhand': [101, 102, 103], 'West Bengal': [104, 105, 106]}

# %%
dropout['Primary_Boys'].values
# Out:
# array(['0.83', '1.35', '0.47', '3.3', '4.31', '6.57', '11.54', '15.84',
#        '11.51', '7.02', '8.19', '16.07', 'NR', '2.38', '0.35', 'NR', 'NR',
#        'NR', '4.24', '1.45', '3.08', 'NR', '1.05', '1.6', 'NR', '1.06',
#        '1.8', 'NR', 'NR', 'NR', 'NR', '0.08', '0.63', '0.21', '0.5',
#        '0.82', '1.48', '0.22', '5.54', '0.51', '0.57', '0.46', '6.8',
#        '5.53', '6.98', '7.36', '6.89', '5.91', '3.4', '2.42', '2.03',
#        'NR', 'NR', 'NR', '2.3', '0', 'NR', '5.75', '9.91', '6.48', '0.88',
#        '0.51', '1.26', '10.24', '17.27', '9.5', '11.32', '11.3', '10.35',
#        '24.27', '12.57', '10.17', '7.11', '19.09', '6.18', '3.63', '2.83',
#        '2.91', '0.25', '0.76', '0.36', '1.99', '1.35', '2.89', '7.2',
#        '7.76', '5.02', '4.78', '5.55', '3.75', '4.02', '0.53', 'NR',
#        '6.04', '2.21', '2.31', '3.63', '1.37', '10.53', '7.91', '9.08',
#        '1.14', '3.28', '4.37', '6.88', '3.44', '2.13', '4.68', '4.53',
#        '4.36'], dtype=object)

# %%
dropout.replace(['NR','Uppe_r_Primary'], np.nan,inplace=True)

# %%
dropout.fillna(value=2,inplace=True)

# %%
dropout.head(20)
# Out:
#               State_UT     year Primary_Boys Primary_Girls Primary_Total  \
# 0        A & N Islands  2012-13         0.83          0.51          0.68
# 1        A & N Islands  2013-14         1.35          1.06          1.21
# 2        A & N Islands  2014-15         0.47          0.55          0.51
# 3       Andhra Pradesh  2012-13          3.3          3.05          3.18
# 4       Andhra Pradesh  2013-14         4.31          4.39          4.35
# 5       Andhra Pradesh  2014-15         6.57          6.89          6.72
# 6   Arunachal  Pradesh  2013-14        11.54         10.22         10.89
# 7    Arunachal Pradesh  2012-13        15.84         14.44         15.16
# 8    Arunachal Pradesh  2014-15        11.51         10.09         10.82
# 9                Assam  2012-13         7.02          5.46          6.24
# 10               Assam  2013-14         8.19          6.68          7.44
# 11               Assam  2014-15        16.07         14.65         15.36
# 12               Bihar  2012-13            2             2             2
# 13               Bihar  2013-14         2.38          1.79          2.09
# 14               Bihar  2014-15         0.35             2             2
# 15          Chandigarh  2012-13            2             2             2
# 16          Chandigarh  2013-14            2             2             2
# 17          Chandigarh  2014-15            2             2             2
# 18        Chhattisgarh  2012-13         4.24          4.05          4.14
# 19        Chhattisgarh  2013-14         1.45          1.38          1.42
#
#    Upper Primary_Boys Upper Primary_Girls Upper Primary_Total Secondary _Boys  \
# 0                   2                1.09                1.23            5.57
# 1                   2                1.54                0.51            8.36
# 2                1.44                1.95                1.69           11.47
# 3                3.21                3.51                3.36           12.21
# 4                3.46                4.12                3.78           11.95
# 5                5.09                5.32                 5.2           15.81
# 6                4.44                6.74                5.59           16.08
# 7                5.86                9.06                7.47           13.99
# 8                5.31                8.08                6.71           18.33
# 9                7.89                6.55                 7.2           25.65
# 10                7.6                6.54                7.05           28.59
# 11              10.45               10.56               10.51           24.64
# 12                  2                   2                   2           29.11
# 13               2.77                3.19                2.98           24.67
# 14               4.14                4.01                4.08           25.21
# 15                  2                0.88                 0.1               2
# 16               0.72                1.55                1.08               2
# 17               0.01                0.96                0.44               2
# 18               6.09                4.73                5.42           14.82
# 19               4.09                3.51                 3.8            24.1
#
#    Secondary _Girls Secondary _Total HrSecondary_Boys HrSecondary_Girls  \
# 0              5.55             5.56            17.66             10.15
# 1              5.98              7.2            18.94              12.2
# 2              8.16             9.87            21.05             12.21
# 3             13.25            12.72             2.66                 2
# 4             13.37            12.65            12.65             10.85
# 5              15.6            15.71                2                 2
# 6             12.75            14.49            18.57             15.49
# 7             11.77            12.93             7.85              2.14
# 8             15.81            17.11            19.37             17.44
# 9             27.79            26.77             4.87               4.5
# 10             32.1            30.43             7.62              6.83
# 11            29.28            27.06                2                 2
# 12            31.28            30.14                2                 2
# 13            26.05            25.33                2                 2
# 14            26.62             25.9                2                 2
# 15                2                2            16.32             10.09
# 16                2                2            13.24              8.49
# 17                2                2             12.1              8.41
# 18            14.89            14.86                2                 2
# 19            22.72            23.41                2              2.13
#
#    HrSecondary_Total
# 0              14.14
# 1              15.87
# 2              16.93
# 3               0.35
# 4              11.79
# 5                  2
# 6              17.07
# 7               5.11
# 8              18.42
# 9               4.69
# 10              7.24
# 11                 2
# 12                 2
# 13                 2
# 14                 2
# 15             13.65
# 16             11.28
# 17             10.55
# 18                 2
# 19                 2

# %%
dropout['Primary_Boys']=dropout['Primary_Boys'].apply(lambda x: float(x))

# %%
#primary_boys=dropout['Primary_Boys'].values.astype(np.float32)
dropout['Primary_Girls']=dropout['Primary_Girls'].values.astype(np.float32)

# %%
dropout['Upper Primary_Boys'].values
# Out:
# array([2, 2, '1.44', '3.21', '3.46', '5.09', '4.44', '5.86', '5.31',
#        '7.89', '7.6', '10.45', 2, '2.77', '4.14', 2, '0.72', '0.01',
#        '6.09', '4.09', '6.47', '2.59', '3.31', '3.7', 2, '3.42', '3.14',
#        2, '3.13', '0.95', 2, 2, 2, '2.75', '3.52', '4.65', '0.18', '1.97',
#        '5.5', '0.52', '0.6', '0.5', '5.51', '3.86', '4.98', '4.99',
#        '7.19', '9.01', '4.96', '2.31', '3.46', 2, 2, 2, '0.97', '1.16',
#        '2.37', '6.79', '9.88', '7.78', '0.89', 2, '0.89', '5.48', '7.48',
#        '3.61', '8.43', '6.34', '6.77', '19.35', '6.61', '5.46', '10.15',
#        '18.08', '7.87', '4.1', '3.11', '4.11', '0.33', '0.37', '0.44',
#        '2.58', '2.52', '2.95', '2.86', '4.49', '2.54', '2.6', '6.35',
#        '2.07', '0.38', '4.38', 2, '4.63', '2.43', '3.1', '3.21', '2.37',
#        2, 2, '0.78', 2, '1.78', '0.79', '6.29', '5.63', '5.84', '2.3',
#        '3.09', '3.49'], dtype=object)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
dropout.describe()
# Out:
#        Primary_Boys  Primary_Girls
# count    110.000000     110.000000
# mean       4.566182       4.283545
# std        4.468224       4.359137
# min        0.000000       0.260000
# 25%        1.510000       1.265000
# 50%        2.900000       2.440000
# 75%        6.742500       5.870000
# max       24.270000      23.930000

# %%
dropout.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110 entries, 0 to 109
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   State_UT             110 non-null    object
#  1   year                 110 non-null    object
#  2   Primary_Boys         110 non-null    float64
#  3   Primary_Girls        110 non-null    float32
#  4   Primary_Total        110 non-null    object
#  5   Upper Primary_Boys   110 non-null    object
#  6   Upper Primary_Girls  110 non-null    object
#  7   Upper Primary_Total  110 non-null    object
#  8   Secondary _Boys      110 non-null    object
#  9   Secondary _Girls     110 non-null    object
#  10  Secondary _Total     110 non-null    object
#  11  HrSecondary_Boys     110 non-null    object
#  12  HrSecondary_Girls    110 non-null    object
#  13  HrSecondary_Total    110 non-null    object
# dtypes: float32(1), float64(1), object(12)
# memory usage: 11.7+ KB

# %%
years=data_wb['year'].values;
print(years)
# Out:
# ['2012-13' '2013-14' '2014-15']

# %%
plt.figure(figsize= (45,15))

sns.countplot(dropout['State_UT'])
# Out:
# C:\Users\dell\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='State_UT', ylabel='count'>

# %%
data_wb.head()
# Out:
#         State_UT     year Primary_Boys Primary_Girls Primary_Total  \
# 104  West Bengal  2012-13         6.88          5.71           6.3
# 105  West Bengal  2013-14         3.44          2.37          2.91
# 106  West Bengal  2014-15         2.13          0.79          1.47
#
#     Upper Primary_Boys Upper Primary_Girls Upper Primary_Total  \
# 104               6.29                4.16                5.18
# 105               5.63                 3.1                4.31
# 106               5.84                2.88                 4.3
#
#     Secondary _Boys Secondary _Girls Secondary _Total HrSecondary_Boys  \
# 104           14.95            19.41             17.3             7.81
# 105           16.73            19.77            18.34             8.03
# 106           16.33            19.06             17.8             8.18
#
#     HrSecondary_Girls HrSecondary_Total
# 104              8.49              8.13
# 105              7.76               7.9
# 106              8.04              8.11

# %%
plt.bar(data_wb['Primary_Girls'],data_wb['year'] )
plt.xlabel('Primary_Girls')
plt.ylabel('Year')
plt.title('Year basis Primary_Girls ratio in west bengal')
plt.show()

# %%
dropout['Secondary _Girls']=dropout['Secondary _Girls'].values.astype(np.float)

plt.bar(dropout['Secondary _Girls'],dropout['year'])
plt.xlabel('Secondary _Girls')
plt.ylabel('Year')
plt.title('Year basis Secondary _Girls ratio')
plt.show()
# Out:
# <ipython-input-25-56b3dfa46c24>:1: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dropout['Secondary _Girls']=dropout['Secondary _Girls'].values.astype(np.float)

# %%
plt.bar(dropout['Primary_Boys'],dropout['year'] )
plt.xlabel('Primary Boys')
plt.ylabel('Year')
plt.title('Year basis primary boys ratio')
plt.show()

# %%
plt.bar(data_wb['Upper Primary_Girls'],data_wb['year'] )
plt.xlabel('Upper Primary_Girls')
plt.ylabel('year')
plt.title('Upper Primary_Girls ratio vs year ')
plt.show()

# %%
plt.bar(data_wb['Upper Primary_Girls'],data_wb['year'] )
plt.xlabel('Upper Primary_Girls')
plt.ylabel('year')
plt.title('Upper Primary_Girls ratio vs year ')
plt.show()

# %%
dropout['HrSecondary_Girls']=dropout['HrSecondary_Girls'].values.astype(np.float)
plt.hist(dropout['HrSecondary_Girls'])
# Out:
# <ipython-input-29-5d203b6c729d>:1: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dropout['HrSecondary_Girls']=dropout['HrSecondary_Girls'].values.astype(np.float)
# (array([55., 22., 19., 10.,  3.,  0.,  0.,  0.,  0.,  1.]),
#  array([ 0.3  ,  3.875,  7.45 , 11.025, 14.6  , 18.175, 21.75 , 25.325,
#         28.9  , 32.475, 36.05 ]),
#  <BarContainer object of 10 artists>)

# %%
dropout.columns
# Out:
# Index(['State_UT', 'year', 'Primary_Boys', 'Primary_Girls', 'Primary_Total',
#        'Upper Primary_Boys', 'Upper Primary_Girls', 'Upper Primary_Total',
#        'Secondary _Boys', 'Secondary _Girls', 'Secondary _Total',
#        'HrSecondary_Boys', 'HrSecondary_Girls', 'HrSecondary_Total'],
#       dtype='object')

# %%
dropout['HrSecondary_Boys']=dropout['HrSecondary_Boys'].values.astype(float)
dropout['Upper Primary_Boys']=dropout['Upper Primary_Boys'].values.astype(float)
dropout['Secondary _Boys']=dropout['Secondary _Boys'].values.astype(float)
dropout['Upper Primary_Girls']=dropout['Upper Primary_Girls'].values.astype(float)
dropout['Secondary _Girls']=dropout['Secondary _Girls'].values.astype(float)

# %%
# Outlier detection using boxplots 
plt.figure(figsize= (20,15))
plt.subplot(4,4,1)
sns.boxplot(dropout['HrSecondary_Girls'])

plt.subplot(4,4,2)
sns.boxplot(dropout['HrSecondary_Boys'])

plt.subplot(4,4,3)
sns.boxplot(dropout['Upper Primary_Boys'])

plt.subplot(4,4,4)
sns.boxplot(dropout['Upper Primary_Girls'])

plt.subplot(4,4,5)
sns.boxplot(dropout['Secondary _Girls'])

plt.subplot(4,4,6)
sns.boxplot(dropout['Secondary _Boys'])
# Out:
# C:\Users\dell\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\dell\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\dell\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\dell\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\dell\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\dell\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Secondary _Boys'>

# %%
dropout['HrSecondary_Girls']=dropout['HrSecondary_Girls'].clip(lower=dropout['HrSecondary_Girls'].quantile(0.05), upper=dropout['HrSecondary_Girls'].quantile(0.95))

# %%
dropout['HrSecondary_Boys']=dropout['HrSecondary_Boys'].clip(lower=dropout['HrSecondary_Boys'].quantile(0.05), upper=dropout['HrSecondary_Boys'].quantile(0.95))

# %%
dropout['Upper Primary_Boys']=dropout['Upper Primary_Boys'].clip(lower=dropout['Upper Primary_Boys'].quantile(0.05), upper=dropout['Upper Primary_Boys'].quantile(0.95))

# %%
dropout['Upper Primary_Girls']=dropout['Upper Primary_Girls'].clip(lower=dropout['Upper Primary_Girls'].quantile(0.05), upper=dropout['Upper Primary_Girls'].quantile(0.95))

# %%
dropout['Secondary _Girls']=dropout['Secondary _Girls'].clip(lower=dropout['Secondary _Girls'].quantile(0.05), upper=dropout['Secondary _Girls'].quantile(0.95))

# %%
dropout['Secondary _Boys']=dropout['Secondary _Boys'].clip(lower=dropout['Secondary _Boys'].quantile(0.05), upper=dropout['Secondary _Boys'].quantile(0.95))

# %%
# Outlier detection using boxplots 
plt.figure(figsize= (20,15))
plt.subplot(4,4,1)
sns.boxplot(dropout['HrSecondary_Girls'])

plt.subplot(4,4,2)
sns.boxplot(dropout['HrSecondary_Boys'])

plt.subplot(4,4,3)
sns.boxplot(dropout['Upper Primary_Boys'])

plt.subplot(4,4,4)
sns.boxplot(dropout['Upper Primary_Girls'])

plt.subplot(4,4,5)
sns.boxplot(dropout['Secondary _Girls'])

plt.subplot(4,4,6)
sns.boxplot(dropout['Secondary _Boys'])
# Out:
# C:\Users\dell\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\dell\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\dell\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\dell\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\dell\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\dell\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Secondary _Boys'>

# %%
sns.pairplot(dropout,diag_kind='kde')

# %%
plt.figure(figsize=(45,15))
sns.countplot(dropout['Primary_Boys'])
# Out:
# C:\Users\dell\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Primary_Boys', ylabel='count'>

# %%
data=dropout[['Primary_Boys','Upper Primary_Boys']].corr()

sns.heatmap(data,annot=True)
# Out:
# <AxesSubplot:>

# %%
data
# Out:
#                     Primary_Boys  Upper Primary_Boys
# Primary_Boys            1.000000            0.685265
# Upper Primary_Boys      0.685265            1.000000
