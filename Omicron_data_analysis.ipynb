# %%
import pandas as pd 
import numpy as np

# %%
df_omicron=pd.read_csv('omicron.csv')

# %%
df_omicron
# Out:
#        Country        Date  Percentage of Omicron
# 0       Angola   9/20/2021                    0.0
# 1       Angola   10/4/2021                    0.0
# 2    Argentina   9/20/2021                    0.0
# 3    Argentina   10/4/2021                    0.0
# 4    Argentina  10/18/2021                    0.0
# ..         ...         ...                    ...
# 547    Vietnam  11/15/2021                    0.0
# 548    Vietnam  11/29/2021                    0.0
# 549    Vietnam  12/13/2021                    0.0
# 550    Vietnam  12/27/2021                    2.0
# 551     Zambia  12/13/2021                  100.0
#
# [552 rows x 3 columns]

# %%
df_india=df_omicron[df_omicron['Country']=='India']

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
#plt.boxplot(df_india['Date'],df_india['Percentage of Omicron'])
fig, axes = plt.subplots(figsize=(14, 8))
plt.title("Percentage of Omicron in Countries")
sns.lineplot(x='Date', y='Percentage of Omicron', hue='Country', data=df_omicron, ax=axes)
# Out:
# <AxesSubplot:title={'center':'Percentage of Omicron in Countries'}, xlabel='Date', ylabel='Percentage of Omicron'>

# %%
fig, axes = plt.subplots(figsize=(14, 8))
plt.title('Omicron trends in india')
sns.lineplot(x='Date', y='Percentage of Omicron', data=df_india, ax=axes)
# Out:
# <AxesSubplot:title={'center':'Omicron trends in india'}, xlabel='Date', ylabel='Percentage of Omicron'>

# %%
five_country=df_omicron[(df_omicron["Country"]=="India") | (df_omicron["Country"]=="Germany") | (df_omicron["Country"]=="Canada") | (df_omicron["Country"]=="Japan") | (df_omicron["Country"]=="Russia")]

# %%
fig, axes = plt.subplots(figsize=(14, 8))
plt.title("Percentage of Omicron in India, Germany, Canada, Japan, Russia")
sns.lineplot(x='Date', y='Percentage of Omicron', hue='Country', data=five_country, ax=axes)
# Out:
# <AxesSubplot:title={'center':'Percentage of Omicron in India, Germany, Canada, Japan, Russia'}, xlabel='Date', ylabel='Percentage of Omicron'>
